# %% [markdown]
# # 03 Exploratory Data Analysis
#
# Here you would perform exploratory analysis on the synthetic credit risk
# data.  Plot distributions, relationships between variables and identify
# patterns that separate risky and safe applicants.
